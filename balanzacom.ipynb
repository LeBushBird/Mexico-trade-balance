# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
balanza = pd.read_csv('balanza.csv')
balanza
# Out:
#     Periodos  Importaciones  Exportaciones  Unnamed: 3  Unnamed: 4
# 0    1991/01       3663.408       3256.379         NaN         NaN
# 1    1991/02       3557.444       3133.354         NaN         NaN
# 2    1991/03       3517.526       3386.678         NaN         NaN
# 3    1991/04       4207.025       3713.110         NaN         NaN
# 4    1991/05       4186.364       3680.416         NaN         NaN
# ..       ...            ...            ...         ...         ...
# 367  2021/08      44215.640      40471.381         NaN         NaN
# 368  2021/09      44078.456      41754.650         NaN         NaN
# 369  2021/10      44658.126      41859.338         NaN         NaN
# 370  2021/11      45698.670      45651.796         NaN         NaN
# 371  2021/12      47102.458      47705.675         NaN         NaN
#
# [372 rows x 5 columns]

# %%
total = balanza['Exportaciones'] - balanza['Importaciones']

x_axis = [i for i in range(0,365,12)]
labels = [j for j in range(1991,2022)]

plt.figure(figsize=(20, 10))
plt.bar(balanza['Periodos'], total)
plt.xticks(x_axis, labels)
plt.style.use('Solarize_Light2')
plt.show()
